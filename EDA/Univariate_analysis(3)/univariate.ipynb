# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/Users/macbookair/Desktop/Machine Learning/EDA/Univariate_analysis(3)/bollywood.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
df.sample(10)
# Out:
#      SlNo Release Date       MovieName ReleaseTime    Genre  Budget  \
# 148   149    23-May-14   Kochadaiiyaan          HS   Action     150
# 130   131     6-Sep-13         Zanjeer          LW   Action      75
# 34     35    21-Feb-14         Highway           N    Drama      30
# 138   139    23-Jan-15            Baby           N   Action      60
# 15     16    18-Jan-13         Bandook           N   Action       4
# 122   123    15-Nov-13           Rajjo          FS  Romance      12
# 86     87    28-Mar-14     Youngistaan           N    Drama      26
# 104   105    12-Jul-13       B.A. Pass           N    Drama       2
# 6       7    19-Sep-14   Daawat-E-Ishq           N   Comedy      30
# 70     71     3-May-13  Bombay Talkies           N    Drama       6
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 148               120.00       4740727         13466             2649
# 130                18.20       2539431          5634              922
# ...

# %% [markdown]
# # catagorical

# %%
sns.countplot(data=df, x='Genre')
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Comedy      36
# Drama       35
# Thriller    29
# Romance     25
# Action      24
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='ReleaseTime')
# Out:
# <Axes: xlabel='ReleaseTime', ylabel='count'>

# %%
df['ReleaseTime'].value_counts()
# Out:
# ReleaseTime
# N     99
# HS    18
# FS    17
# LW    15
# Name: count, dtype: int64

# %% [markdown]
# Piechart

# %%
df['Genre'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='Set3')
# Out:
# <Axes: ylabel='count'>

# %%
df['ReleaseTime'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='Set3')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical Data

# %% [markdown]
# a. Histogram

# %%
df.sample(10)
# Out:
#      SlNo Release Date                         MovieName ReleaseTime  \
# 61     62    12-Apr-13           Commando-A One Man Army          LW
# 42     43    19-Sep-14                        Khoobsurat           N
# 74     75    25-Apr-14                     Revolver Rani           N
# 104   105    12-Jul-13                         B.A. Pass           N
# 82     83    31-May-13           Yeh Jawaani Hai Deewani           N
# 15     16    18-Jan-13                           Bandook           N
# 62     63    19-Apr-13                     Ek Thi Daayan          FS
# 47     48    15-Mar-13                         Jolly LLB           N
# 40     41     8-Mar-13  Saheb, Biwi Aur Gangster Returns          FS
# 97     98     5-Jul-13                           Lootera           N
#
#         Genre  Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# 61     Action      22                21.00       3162465          7519
# ...

# %%
plt.hist(df['Budget'], bins=5, color='skyblue', edgecolor='black')
# Out:
# (array([104.,  30.,   8.,   4.,   3.]),
#  array([  2. ,  31.6,  61.2,  90.8, 120.4, 150. ]),
#  <BarContainer object of 5 artists>)

# %%
df['Budget'].describe()
# Out:
# count    149.000000
# mean      29.442953
# std       28.237981
# min        2.000000
# 25%       11.000000
# 50%       21.000000
# 75%       35.000000
# max      150.000000
# Name: Budget, dtype: float64

# %%
plt.hist(df['BoxOfficeCollection'], bins=5, color='skyblue', edgecolor='black')
# Out:
# (array([137.,   4.,   7.,   0.,   1.]),
#  array([1.00000e-02, 1.47008e+02, 2.94006e+02, 4.41004e+02, 5.88002e+02,
#         7.35000e+02]),
#  <BarContainer object of 5 artists>)

# %%
df['BoxOfficeCollection'].describe()
# Out:
# count    149.000000
# mean      55.667248
# std       94.494531
# min        0.010000
# 25%        8.780000
# 50%       28.000000
# 75%       57.450000
# max      735.000000
# Name: BoxOfficeCollection, dtype: float64

# %%
sns.kdeplot(df['Budget'], shade=True, color='blue')
# Out:
# /var/folders/4g/9m2h6m6x0lxbsngvlhdmn_dm0000gn/T/ipykernel_7058/3412039853.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Budget'], shade=True, color='blue')
# <Axes: xlabel='Budget', ylabel='Density'>

# %% [markdown]
# c.Boxplot

# %%
sns.boxplot(y=df['BoxOfficeCollection'], color='lightgreen')
# Out:
# <Axes: ylabel='BoxOfficeCollection'>

# %%
sns.kdeplot(df['BoxOfficeCollection'], shade=True, color='green')
# Out:
# /var/folders/4g/9m2h6m6x0lxbsngvlhdmn_dm0000gn/T/ipykernel_7058/2518639890.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['BoxOfficeCollection'], shade=True, color='green')
# <Axes: xlabel='BoxOfficeCollection', ylabel='Density'>

# %%
sns.boxplot(y=df['Budget'], color='lightblue')
# Out:
# <Axes: ylabel='Budget'>
