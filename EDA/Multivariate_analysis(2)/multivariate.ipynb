# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/Users/macbookair/Desktop/Machine Learning/EDA/Multivariate_analysis(2)/bollywood.csv')

# %%
df.head()
# Out:
#    SlNo Release Date           MovieName ReleaseTime     Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW   Romance      36
# 1     2     4-Jan-13        Table No. 21           N  Thriller      10
# 2     3    18-Jul-14  Amit Sahni Ki List           N    Comedy      10
# 3     4     4-Jan-13    Rajdhani Express           N     Drama       7
# 4     5     4-Jul-14        Bobby Jasoos           N    Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
df.sample(10)
# Out:
#      SlNo Release Date                MovieName ReleaseTime     Genre  Budget  \
# 28     29    18-Jul-14             Hate Story 2           N  Thriller      12
# 75     76    28-Feb-14   Shaadi Ke Side Effects           N    Comedy      50
# 123   124    22-Nov-13     Gori Tere Pyaar Mein           N   Romance      30
# 64     65    26-Apr-13               Aashiqui 2           N   Romance      12
# 92     93     2-Oct-14                Bang Bang          FS    Action     140
# 129   130    25-Oct-13             Mickey Virus           N    Comedy      11
# 107   108    19-Jul-13                    D Day           N    Action      30
# 70     71     3-May-13           Bombay Talkies           N     Drama       6
# 61     62    12-Apr-13  Commando-A One Man Army          LW    Action      22
# 66     67    31-Jan-14               One by Two           N   Romance      12
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %% [markdown]
# # 1. Scatterplot(cat-cat)

# %%
sns.scatterplot(data=df, x='Budget', y='BoxOfficeCollection')
# Out:
# <Axes: xlabel='Budget', ylabel='BoxOfficeCollection'>

# %%
sns.scatterplot(data=df, x='Budget', y='BoxOfficeCollection', hue='Genre')
# Out:
# <Axes: xlabel='Budget', ylabel='BoxOfficeCollection'>

# %%
sns.scatterplot(data=df, x='Budget', y='BoxOfficeCollection', hue='Genre',style='ReleaseTime')
# Out:
# <Axes: xlabel='Budget', ylabel='BoxOfficeCollection'>

# %% [markdown]
# # Bar plot (num-cat)

# %%
df.sample(5)
# Out:
#      SlNo Release Date           MovieName ReleaseTime     Genre  Budget  \
# 83     84    10-Jan-14            Yaariyan          LW   Romance      19
# 101   102    12-Jul-13  Bhaag Milkha Bhaag           N     Drama      30
# 47     48    15-Mar-13           Jolly LLB           N    Comedy      10
# 31     32    15-Feb-13            Murder 3          FS  Thriller      12
# 99    100    16-May-14           The Xpose          HS  Thriller      16
#
#      BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 83                  40.0       3331082          4853              767
# 101                164.0       2635390          4622              456
# 47                  32.7       1741424          3024              181
# 31                  25.0       2249055          1879              747
# 99                  29.0       3707889          3512             1292

# %%
sns.barplot(data=df, x='Genre', y='Budget')
# Out:
# <Axes: xlabel='Genre', ylabel='Budget'>

# %%
sns.barplot(data=df, x='Genre', y='Budget', hue='ReleaseTime')
# Out:
# <Axes: xlabel='Genre', ylabel='Budget'>

# %% [markdown]
# # 3. Box plot

# %%
sns.boxplot(data=df, x='Genre', y='Budget')
# Out:
# <Axes: xlabel='Genre', ylabel='Budget'>

# %%
sns.boxplot(data=df, x='Genre', y='Budget', hue='ReleaseTime')
# Out:
# <Axes: xlabel='Genre', ylabel='Budget'>

# %% [markdown]
# # 4. distplot

# %%
sns.kdeplot(
    data=df,
    x='Budget',
    hue='Genre',
    fill=True
)
# Out:
# <Axes: xlabel='Budget', ylabel='Density'>

# %% [markdown]
# # 5.heatmap(cat-cat)

# %%
df.head()
# Out:
#    SlNo Release Date           MovieName ReleaseTime     Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW   Romance      36
# 1     2     4-Jan-13        Table No. 21           N  Thriller      10
# 2     3    18-Jul-14  Amit Sahni Ki List           N    Comedy      10
# 3     4     4-Jan-13    Rajdhani Express           N     Drama       7
# 4     5     4-Jul-14        Bobby Jasoos           N    Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %%
sns.heatmap(pd.crosstab(df['Genre'], df['ReleaseTime']), annot=True, fmt='d')
# Out:
# <Axes: xlabel='ReleaseTime', ylabel='Genre'>

# %%
df.groupby('Genre')['Budget'].mean()
# Out:
# Genre
# Action      56.958333
# Comedy      25.277778
# Drama       24.200000
# Romance     25.160000
# Thriller    21.862069
# Name: Budget, dtype: float64

# %%
df.groupby('ReleaseTime')['Budget'].mean()
# Out:
# ReleaseTime
# FS    40.647059
# HS    28.722222
# LW    46.400000
# N     25.080808
# Name: Budget, dtype: float64

# %% [markdown]
# # ClusterMap(cat-cat)

# %%
sns.clustermap(pd.crosstab(df['Genre'], df['ReleaseTime']))
