# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/Users/macbookair/Desktop/Machine Learning/EDA/Univariate_analysis(2)/placement (1).csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.sample(5)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 1            1   5.9  106.0          0
# 82          82   6.5   37.0          1
# 51          51   4.8  141.0          0
# 87          87   5.7  132.0          1
# 99          99   6.2  113.0          1

# %%
df =df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %% [markdown]
# # 1.Catergorical Data

# %% [markdown]
# a. Countplot

# %%
sns.countplot(x='placement',data=df)
# Out:
# <Axes: xlabel='placement', ylabel='count'>

# %%
df['placement'].value_counts()
# Out:
# placement
# 1    50
# 0    50
# Name: count, dtype: int64

# %%
df['placement'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='placement'>

# %% [markdown]
# b.PieChart

# %%
df['placement'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# a. Histogram

# %%
df.sample(10)
# Out:
#     cgpa     iq  placement
# 61   7.3  137.0          1
# 24   4.7  121.0          0
# 82   6.5   37.0          1
# 17   3.3  183.0          0
# 1    5.9  106.0          0
# 74   6.7  154.0          1
# 98   6.3  103.0          1
# 37   8.1  149.0          1
# 94   4.7   52.0          0
# 35   6.8   90.0          1

# %%
import matplotlib.pyplot as plt
plt.hist(df['cgpa'],bins=5)
# Out:
# (array([ 6., 29., 27., 27., 11.]),
#  array([3.3 , 4.34, 5.38, 6.42, 7.46, 8.5 ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df['iq'],bins=5)
# Out:
# (array([14., 25., 41., 15.,  5.]),
#  array([ 37. ,  76.2, 115.4, 154.6, 193.8, 233. ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# b.Distplot

# %%
sns.kdeplot(x='cgpa', data=df, fill=False)
# Out:
# <Axes: xlabel='cgpa', ylabel='Density'>

# %% [markdown]
# c.Boxplot

# %%
sns.boxplot(df['cgpa'])
# Out:
# <Axes: ylabel='cgpa'>

# %%
df['cgpa'   ].describe()
# Out:
# count    100.000000
# mean       5.991000
# std        1.143634
# min        3.300000
# 25%        5.075000
# 50%        6.000000
# 75%        6.900000
# max        8.500000
# Name: cgpa, dtype: float64

# %%
df['iq'].describe()
# Out:
# count    100.000000
# mean     123.580000
# std       39.944198
# min       37.000000
# 25%      101.500000
# 50%      127.500000
# 75%      149.000000
# max      233.000000
# Name: iq, dtype: float64
